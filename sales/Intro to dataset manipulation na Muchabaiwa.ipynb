# %% [markdown]
# # Intro to dataset mani

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
use_cols = [
    'loan_amnt','int_rate', 'annual_inc', 'open_acc', 'loan_status', 'open_il_12m'
]

data = pd.read_csv('loan.csv', usecols=use_cols).sample(10000, random_state = 44) #set a seed for reproducibility

data.head(20)
# Out:
#         loan_amnt  int_rate  annual_inc loan_status  open_acc  open_il_12m
# 131079    23675.0     15.80     90000.0     Current       4.0          NaN
# 384935     7500.0     11.67    102000.0     Current      11.0          NaN
# 73585     11150.0      9.25     72000.0  Fully Paid       6.0          NaN
# 660814     8000.0      6.24    101400.0     Current      20.0          NaN
# 349757    34000.0     19.52     99000.0     Current      12.0          NaN
# 108011     8725.0     15.88     45700.0  Fully Paid       5.0          NaN
# 616081    30000.0     17.86    185000.0     Current       8.0          NaN
# 821155    10000.0     16.55     50000.0     Current      12.0          NaN
# 444724    10200.0     25.83     37000.0     Default       8.0          NaN
# 49347     18000.0      8.90     40000.0     Current       9.0          NaN
# 508395    24000.0     10.64     62500.0     Current      11.0          NaN
# ...

# %%
fig = data.loan_amnt.hist(bins=50)
fig.set_title('Loan')
# Out:
# Text(0.5,1,'Loan')

# %%
data['defaulted'] = np.where(data.loan_status.isin(['Default']), 1,0)
data.defaulted.mean()
# Out:
# 0.0017

# %%
data.head(10)
# Out:
#         loan_amnt  int_rate  annual_inc loan_status  open_acc  open_il_12m  \
# 131079    23675.0     15.80     90000.0     Current       4.0          NaN
# 384935     7500.0     11.67    102000.0     Current      11.0          NaN
# 73585     11150.0      9.25     72000.0  Fully Paid       6.0          NaN
# 660814     8000.0      6.24    101400.0     Current      20.0          NaN
# 349757    34000.0     19.52     99000.0     Current      12.0          NaN
# 108011     8725.0     15.88     45700.0  Fully Paid       5.0          NaN
# 616081    30000.0     17.86    185000.0     Current       8.0          NaN
# 821155    10000.0     16.55     50000.0     Current      12.0          NaN
# 444724    10200.0     25.83     37000.0     Default       8.0          NaN
# 49347     18000.0      8.90     40000.0     Current       9.0          NaN
#
#         defaulted
# 131079          0
# 384935          0
# 73585           0
# 660814          0
# 349757          0
# 108011          0
# ...

# %%
data.loan_status.unique()
# Out:
# array(['Current', 'Fully Paid', 'Default', 'Charged Off',
#        'Late (31-120 days)', 'Issued', 'In Grace Period',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off',
#        'Late (16-30 days)'], dtype=object)

# %%
#fig =data.loan_status.hist(bins=50)
fig = data['loan_status'].value_counts().plot.bar()
fig.set_title('Loan Status')
fig.set_ylabel('Number Of Customers')
# Out:
# Text(0,0.5,'Number Of Customers')
